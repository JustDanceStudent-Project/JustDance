# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
from scipy import signal

data = pd.read_excel('Anniya.xlsx', skiprows=1)
readings = data.iloc[1973:4005, 1:10]
dance = data.iloc[:, 0]
x = np.arange(0,2032)
accX = []
accX = readings[0]
n = 15
b = [1.0 / n] * n
a = 1
yy = signal.lfilter(b,a,accX)

f, axarr = plt.subplots(2, sharex=True)
axarr[0].plot(x, yy, c="b")
axarr[0].set_title('Sharing X axis')
axarr[1].plot(x, accX, c="r")
plt.show()
